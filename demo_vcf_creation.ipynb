# %%
from viper.vcf_generator import generate_vcf_from_alignment

generate_vcf_from_alignment(
    ref_fasta="data/example_sequences.fasta",
    aligned_fasta="data/example_aligned_sequences.fasta",
    output_vcf="data/generated_variants.vcf"
)
