# %%
from viper.vcf_generator import generate_vcf_from_alignment

generate_vcf_from_alignment(
    ref_fasta="data/sars_cov/sars_cov_reference.fasta",
    aligned_fasta="data/sars_cov/sars_cov_aligned.fasta",
    output_vcf="data/sars_cov/sars_cov_mutations.vcf"
)
